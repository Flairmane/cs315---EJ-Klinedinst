# %% [markdown]
# <a href="https://colab.research.google.com/github/Flairmane/cs315---EJ-Klinedinst/blob/main/Matrix_Decryption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
top = [692,440,631,428,584,419,793,816,488,759,723,741,473,719,713,787,224,801,699,473,500,541,538,495,495,524,431,740,340,569,507,564,524,316,475]
bottom = [304,168,265,198,238,161,339,350,228,325,311,313,179,311,305,343,96,341,301,179,234,221,212,197,199,204,165,320,154,225,201,224,210,142,189]

topEncrypt = [2,-4]
bottomEncrypt = [-1,3]

message = []

for i in range(int(len(top))):
  total = round((1/2)*(topEncrypt[0]*top[i]+topEncrypt[1]*bottom[i]))
  message.append(total)

for i in range(int(len(bottom))):
  total = round((1/2)*(bottomEncrypt[0]*top[i]+bottomEncrypt[1]*bottom[i]))
  message.append(total)

print(message)
# Out:
# [84, 104, 101, 32, 108, 97, 115, 116, 32, 109, 101, 115, 115, 97, 103, 101, 32, 119, 97, 115, 32, 99, 114, 101, 97, 116, 101, 100, 32, 119, 105, 116, 104, 32, 97, 110, 32, 82, 83, 65, 32, 112, 117, 98, 108, 105, 99, 32, 107, 101, 121, 32, 111, 102, 32, 101, 61, 49, 48, 51, 44, 32, 110, 61, 53, 48, 54, 53, 55, 46]
